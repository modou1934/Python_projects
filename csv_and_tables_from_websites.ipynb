# %%
import pandas as pd

# %% [markdown]
# ## 1 Read a .csv from a URL with Pandas

# %%
df_premier_25 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2526/E0.csv")

# %%
df_premier_25
# Out:
#     Div        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  15/08/2025  20:00       Liverpool  Bournemouth     4     2   H     1
# 1    E0  16/08/2025  12:30     Aston Villa    Newcastle     0     0   D     0
# 2    E0  16/08/2025  15:00        Brighton       Fulham     1     1   D     0
# 3    E0  16/08/2025  15:00      Sunderland     West Ham     3     0   H     0
# 4    E0  16/08/2025  15:00       Tottenham      Burnley     3     0   H     1
# ..   ..         ...    ...             ...          ...   ...   ...  ..   ...
# 185  E0  30/12/2025  20:15      Man United       Wolves     1     1   D     1
# 186  E0  01/01/2026  17:30  Crystal Palace       Fulham     1     1   D     1
# 187  E0  01/01/2026  17:30       Liverpool        Leeds     0     0   D     0
# 188  E0  01/01/2026  20:00       Brentford    Tottenham     0     0   D     0
# 189  E0  01/01/2026  20:00      Sunderland     Man City     0     0   D     0
#
# ...

# %%
df_premier_25.rename(columns={"FTHG": "Home_goals","FTAG": "Away_goals"})
# Out:
#     Div        Date   Time        HomeTeam     AwayTeam  Home_goals  \
# 0    E0  15/08/2025  20:00       Liverpool  Bournemouth           4
# 1    E0  16/08/2025  12:30     Aston Villa    Newcastle           0
# 2    E0  16/08/2025  15:00        Brighton       Fulham           1
# 3    E0  16/08/2025  15:00      Sunderland     West Ham           3
# 4    E0  16/08/2025  15:00       Tottenham      Burnley           3
# ..   ..         ...    ...             ...          ...         ...
# 185  E0  30/12/2025  20:15      Man United       Wolves           1
# 186  E0  01/01/2026  17:30  Crystal Palace       Fulham           1
# 187  E0  01/01/2026  17:30       Liverpool        Leeds           0
# 188  E0  01/01/2026  20:00       Brentford    Tottenham           0
# 189  E0  01/01/2026  20:00      Sunderland     Man City           0
#
#      Away_goals FTR  HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# ...
