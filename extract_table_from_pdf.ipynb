# %% [markdown]
# ## this is my first notebook

# %%
import camelot as cm
# Out:
# C:\Users\Utente\Desktop\Python_projects\.venv\Lib\site-packages\pypdf\_crypt_providers\_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4

# %%
ls
# Out:
#  Il volume nell'unit… C non ha etichetta.
#  Numero di serie del volume: 5A68-D52C
#
#  Directory di C:\Users\Utente
#
# 01/01/2026  19:06    <DIR>          .
# 29/08/2024  11:40    <DIR>          ..
# 13/10/2025  06:13    <DIR>          .android
# 23/10/2025  23:11    <DIR>          .aws
# 23/10/2025  23:11    <DIR>          .azure
# 16/10/2025  17:56    <DIR>          .bun
# 16/10/2025  17:56    <DIR>          .cache
# 17/05/2025  15:27    <DIR>          .chocolatey
# 27/12/2025  19:33    <DIR>          .claude
# 27/12/2025  19:33            39.689 .claude.json
# 27/12/2025  19:33            39.643 .claude.json.backup
# 22/10/2025  19:04           248.508 .claude.json.corrupted.1761156276965
# 22/10/2025  19:28           256.505 .claude.json.corrupted.1761157716281
# 22/10/2025  19:28           223.536 .claude.json.corrupted.1761157716317
# 22/10/2025  19:33           255.403 .claude.json.corrupted.1761157987427
# ...

# %%
input_pdf = cm.read_pdf("india_factsheet_economic_n_hdi.pdf", flavor='lattice', pages='1,2')
# Out:
# Overwriting cache for 0 71
# Overwriting cache for 0 71
# Overwriting cache for 0 71

# %%
input_pdf
# Out:
# <TableList n=4>

# %%
for n in input_pdf:
    print(n)
# Out:
# <Table shape=(4, 3)>
# <Table shape=(15, 3)>
# <Table shape=(14, 4)>
# <Table shape=(13, 3)>

# %%
input_pdf[2].df
# Out:
#                                0  \
# 0   Human Development Indicators
# 1                             13
# 2                             14
# 3                             15
# 4                             16
# 5
# 6                             17
# 7                             18
# 8
# 9                             19
# 10
# 11                            20
# 12                            21
# 13                            22
#
#                                                     1       2      3
# 0                                                        2000   2011
# 1                 Human Development Index Value (HDI)   0.461  0.547
# 2                               HDI Rank (out of 187)            134
# 3   Inequality Adjusted Human Development Index Value          0.392
# 4                 Loss in HDI due to Inequalities (%)           28.7
# 5                                                        2001   2011
# ...

# %%
cs = input_pdf[2].df.loc[11:14,1:3]

# %%
cs
# Out:
#                            1     2      3
# 11         Literacy Rate (%)  64.8  74.04
# 12    Male Literacy Rate (%)  75.3  82.14
# 13  Female Literacy Rate (%)  53.7  65.46

# %%
cs = cs.reset_index(drop = True)

# %%
cs
# Out:
#                         KPI  2001   2011
# 0         Literacy Rate (%)  64.8  74.04
# 1    Male Literacy Rate (%)  75.3  82.14
# 2  Female Literacy Rate (%)  53.7  65.46

# %%
cs.columns = ["KPI","2001", "2011"]

# %%
cs
# Out:
#                         KPI  2001   2011
# 0         Literacy Rate (%)  64.8  74.04
# 1    Male Literacy Rate (%)  75.3  82.14
# 2  Female Literacy Rate (%)  53.7  65.46

# %%
cs.loc[:,["2001","2011"]] = cs.loc[:,["2001", "2011"]].astype(float)

# %%
cs
# Out:
#                         KPI  2001   2011
# 0         Literacy Rate (%)  64.8  74.04
# 1    Male Literacy Rate (%)  75.3  82.14
# 2  Female Literacy Rate (%)  53.7  65.46

# %%
cs.to_csv("table_from_pdf.csv")

# %%
ls
# Out:
#  Il volume nell'unit… C non ha etichetta.
#  Numero di serie del volume: 5A68-D52C
#
#  Directory di C:\Users\Utente
#
# 01/01/2026  19:32    <DIR>          .
# 29/08/2024  11:40    <DIR>          ..
# 13/10/2025  06:13    <DIR>          .android
# 23/10/2025  23:11    <DIR>          .aws
# 23/10/2025  23:11    <DIR>          .azure
# 16/10/2025  17:56    <DIR>          .bun
# 16/10/2025  17:56    <DIR>          .cache
# 17/05/2025  15:27    <DIR>          .chocolatey
# 27/12/2025  19:33    <DIR>          .claude
# 27/12/2025  19:33            39.689 .claude.json
# 27/12/2025  19:33            39.643 .claude.json.backup
# 22/10/2025  19:04           248.508 .claude.json.corrupted.1761156276965
# 22/10/2025  19:28           256.505 .claude.json.corrupted.1761157716281
# 22/10/2025  19:28           223.536 .claude.json.corrupted.1761157716317
# 22/10/2025  19:33           255.403 .claude.json.corrupted.1761157987427
# ...

# %%
cs.to_excel("table_from_pdf.xlsx")

# %%
ls
# Out:
#  Il volume nell'unit… C non ha etichetta.
#  Numero di serie del volume: 5A68-D52C
#
#  Directory di C:\Users\Utente
#
# 01/01/2026  19:34    <DIR>          .
# 29/08/2024  11:40    <DIR>          ..
# 13/10/2025  06:13    <DIR>          .android
# 23/10/2025  23:11    <DIR>          .aws
# 23/10/2025  23:11    <DIR>          .azure
# 16/10/2025  17:56    <DIR>          .bun
# 16/10/2025  17:56    <DIR>          .cache
# 17/05/2025  15:27    <DIR>          .chocolatey
# 27/12/2025  19:33    <DIR>          .claude
# 27/12/2025  19:33            39.689 .claude.json
# 27/12/2025  19:33            39.643 .claude.json.backup
# 22/10/2025  19:04           248.508 .claude.json.corrupted.1761156276965
# 22/10/2025  19:28           256.505 .claude.json.corrupted.1761157716281
# 22/10/2025  19:28           223.536 .claude.json.corrupted.1761157716317
# 22/10/2025  19:33           255.403 .claude.json.corrupted.1761157987427
# ...

# %%
import pandas as pd

# %%
cs2 = pd.read_csv("table_from_pdf.csv")
cs2
# Out:
#    Unnamed: 0                       KPI  2001   2011
# 0           0         Literacy Rate (%)  64.8  74.04
# 1           1    Male Literacy Rate (%)  75.3  82.14
# 2           2  Female Literacy Rate (%)  53.7  65.46

# %%
import seaborn as sns

# %%
cs_melted = cs.melt("KPI", var_name="year", value_name="percentage")

# %%
cs_melted
# Out:
#                         KPI  year percentage
# 0         Literacy Rate (%)  2001       64.8
# 1    Male Literacy Rate (%)  2001       75.3
# 2  Female Literacy Rate (%)  2001       53.7
# 3         Literacy Rate (%)  2011      74.04
# 4    Male Literacy Rate (%)  2011      82.14
# 5  Female Literacy Rate (%)  2011      65.46

# %%
sns.barplot(x= "KPI", y ="percentage", hue="year" , data= cs_melted)
# Out:
# <Axes: xlabel='KPI', ylabel='percentage'>
